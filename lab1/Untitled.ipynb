# %%
moscow_zoo = {
    "пума": ["гривистый волк", "леопард", "рысь"],
    "гривистый волк": ["пума", "леопард", "рысь"],
    "леопард": ["пума", "гривистый волк", "рысь"],
    "рысь": ["пума", "гривистый волк", "леопард"],
    "гималайский медведь": ["манул Тимофей", "беркут", "бинтуронг", "белогрудый медведь", "малая панда"],
    "манул Тимофей": ["гималайский медведь", "беркут", "бинтуронг", "белогрудый медведь", "малая панда"],
    "беркут": ["гималайский медведь", "манул Тимофей", "бинтуронг", "белогрудый медведь", "малая панда"],
    "бинтуронг": ["гималайский медведь", "манул Тимофей", "беркут", "белогрудый медведь", "малая панда"],
    "белогрудый медведь": ["гималайский медведь", "манул Тимофей", "беркут", "бинтуронг", "малая панда"],
    "малая панда": ["гималайский медведь", "манул Тимофей", "беркут", "бинтуронг", "белогрудый медведь"],
    "большая панда": [],
    "сова": ["паук"],
    "паук": ["сова"],
    "красный волк": ["носуха"],
    "носуха": ["красный волк"],
    "фламинго": [],
    "андорский кондор": ["гриф", "белохвостый орлан"],
    "гриф": ["андорский кондор", "белохвостый орлан"],
    "белохвостый орлан": ["андорский кондор", "гриф"],
    "равнинный тапир": ["лесной северный олень"],
    "лесной северный олень": ["равнинный тапир"],
    "японский макак": [],
    "павлин": ["синий ушастый фазан", "черный аист"],
    "синий ушастый фазан": ["павлин", "черный аист"],
    "черный аист": ["павлин", "синий ушастый фазан"],
    "тукан": ["какаду", "перепел", "сорока", "кукушка", "ворон", "казуар", "скворец"],
    "какаду": ["тукан", "перепел", "сорока", "кукушка", "ворон", "казуар", "скворец"],
    "перепел": ["тукан", "какаду", "сорока", "кукушка", "ворон", "казуар", "скворец"],
    "сорока": ["тукан", "какаду", "перепел", "кукушка", "ворон", "казуар", "скворец"],
    "кукушка": ["тукан", "какаду", "перепел", "сорока", "ворон", "казуар", "скворец"],
    "ворон": ["тукан", "какаду", "перепел", "сорока", "кукушка", "казуар", "скворец"],
    "казуар": ["тукан", "какаду", "перепел", "сорока", "кукушка", "ворон", "скворец"],
    "скворец": ["тукан", "какаду", "перепел", "сорока", "кукушка", "ворон", "казуар"],
    "гигантский муравьед": ["муравьед", "викунья", "капибара"],
    "муравьед": ["гигантский муравьед", "викунья", "капибара"],
    "викунья": ["гигантский муравьед", "муравьед", "капибара"],
    "капибара": ["гигантский муравьед", "муравьед", "викунья"],
    "гуси": ["утки"],
    "утки": ["гуси"],
    "камышовый кот": ["песец", "лисица", "бобр", "степная кошка", "лесной кот", "ёж", "неясыть", "полярный волк"],
    "песец": ["камышовый кот", "лисица", "бобр", "степная кошка", "лесной кот", "ёж", "неясыть", "полярный волк"],
    "лисица": ["камышовый кот", "песец", "бобр", "степная кошка", "лесной кот", "ёж", "неясыть", "полярный волк"],
    "бобр": ["камышовый кот", "песец", "лисица", "степная кошка", "лесной кот", "ёж", "неясыть", "полярный волк"],
    "степная кошка": ["камышовый кот", "песец", "лисица", "бобр", "лесной кот", "ёж", "неясыть", "полярный волк"],
    "лесной кот": ["камышовый кот", "песец", "лисица", "бобр", "степная кошка", "ёж", "неясыть", "полярный волк"],
    "ёж": ["камышовый кот", "песец", "лисица", "бобр", "степная кошка", "лесной кот", "неясыть", "полярный волк"],
    "неясыть": ["камышовый кот", "песец", "лисица", "бобр", "степная кошка", "лесной кот", "ёж", "полярный волк"],
    "полярный волк": ["камышовый кот", "песец", "лисица", "бобр", "степная кошка", "лесной кот", "ёж", "неясыть"],
    "ядовитые змеи": [],
    "сурок": ["птица-секретарь", "орлан", "орел", "тюлень", "ящерица", "ядозуб", "игуана"],
    "птица-секретарь": ["сурок", "орлан", "орел", "тюлень", "ящерица", "ядозуб", "игуана"],
    "орлан": ["сурок", "птица-секретарь", "орел","тюлень", "ящерица", "ядозуб", "игуана"],
    "орел": ["сурок", "птица-секретарь", "орлан", "тюлень", "ящерица", "ядозуб", "игуана"],
    "тюлень": ["сурок", "птица-секретарь", "орел", "орлан", "ящерица", "ядозуб", "игуана"],
    "ящерица": ["сурок", "птица-секретарь", "орел", "орлан", "тюлень", "ядозуб", "игуана"],
    "ядозуб": ["сурок", "птица-секретарь", "орел", "орлан", "тюлень", "ящерица", "игуана"],
    "игуана": ["сурок", "птица-секретарь", "орел", "орлан", "тюлень", "ящерица", "ядозуб"],
    "черный лебедь": ["обыкновенный фазан"],
    "обыкновенный фазан": ["черный лебедь"],
    "овцебык": [],
    "домашний як": ["енот-полоскун", "кустарниковая собака"],
    "енот-полоскун": ["домашний як", "кустарниковая собака"],
    "кустарниковая собака": ["домашний як", "енот-полоскун"],
    "морж": ["лахтак", "серый тюлень", "сивуч", "морской котик"],
    "лахтак": ["морж", "серый тюлень", "сивуч", "морской котик"],
    "серый тюлень": ["морж", "лахтак", "сивуч", "морской котик"],
    "сивуч": ["морж", "лахтак", "серый тюлень", "морской котик"],
    "морской котик": ["морж", "лахтак", "серый тюлень", "сивуч"],
    "слон": ["жаба"],
    "жаба": ["слон"],
    "пингвин": ["голубь"],
    "голубь": ["пингвин"]
}

def get_neighbors(animal_name):
    return moscow_zoo.get(animal_name, [])

# Пример вызова функции
neighbors_of_timofey = get_neighbors("беркут")
print("Соседи манула Тимофея:", neighbors_of_timofey)
# Out:
# Соседи манула Тимофея: ['гималайский медведь', 'манул Тимофей', 'бинтуронг', 'белогрудый медведь', 'малая панда']
